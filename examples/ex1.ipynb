# %%
import sys
sys.path.append('..')
from common import *
from decomposition import *
from nets import *

# %%
model = LeNet()
decomposed = build(model, decomp='tucker')
# Out:
# ==> Building model..
# LeNet(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): Conv2d(1, 11, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (2): Conv2d(11, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): Conv2d(11, 22, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (2): Conv2d(22, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.25, inplace=False)
#     (1): Sequential(
#       (0): Linear(in_features=9216, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#       (2): Linear(in_features=64, out_features=128, bias=True)
#     )
# ...

# %%
run_all('mnist', model, decomp='tucker', i=10, rate=0.05)
# Out:
# ==> Loading data..
# ==> Building model..
# LeNet(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): Conv2d(1, 11, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (2): Conv2d(11, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): Conv2d(11, 22, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (2): Conv2d(22, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.25, inplace=False)
#     (1): Sequential(
#       (0): Linear(in_features=9216, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
# ...

# %%
run_all('cifar10', model, decomp=None, i=10, rate=0.05)

# %%
x = torch.rand(32, 32)
x_hat = x.reshape(4, 8, 8, 4)
a = matrix_product_state(x, [1, 2, 1])
for i in a:
    print(i.shape)

# %%
trainloader, testloader = load_mnist()

# %%
for i in trainloader:
    print(i[0].squeeze().shape, i[1].shape)
    break
